# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split
from feature_engineering import DataProcessor
from LSTM import LSTMModel
#from RNN import RNNModel
from train import ModelTrainer
import torch.nn as nn

# %%
# Load and preprocess data
dataset_dir = ''
data_processor = DataProcessor(dataset_dir)

# Choose to preprocess data or load saved mappings
preprocess_data = False
char_to_id_file = 'char_to_id.json'
id_to_char_file = 'id_to_char.json'

if preprocess_data:
    ids, char_to_id, id_to_char = data_processor.preprocess()
    data_processor.save_mappings(char_to_id_file, char_to_id, id_to_char_file, id_to_char)
else:
    char_to_id, id_to_char = data_processor.load_mappings(char_to_id_file, id_to_char_file)
print('Mapping loaded')
## Create Dataset sequences with pytorch
#data_processor = DataProcessor(dataset_dir)
dialogue_lines = data_processor.read_dialogue_lines()
text = ' '.join(dialogue_lines.values())
ids = data_processor.text_to_ids(text, char_to_id)
print(len(ids))
dataset = data_processor.create_dataset(ids[:1050])
# Out:
# Mapping loaded
# 5743182

# %%
def train_and_test(input_size,hidden_size,num_layers,num_epochs,batch_size,learning_rate):
  train_loader, val_loader, test_loader=DataProcessor.create_loaders(dataset, 0.8, 0.1, 0.1, 50)
  print('Data Loaded')
  ## Train and Evaluate the model
  # Initialize the LSTM model
  input_size = embedding_size = 50
  hidden_size = 256
  num_layers = 2
  vocab_size = len(char_to_id)
  model = LSTMModel(input_size, hidden_size, vocab_size, num_layers)

  # Move the model to GPU if available
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  #device = torch.device("cpu")
  model.to(device)

  # Define the loss function, learning rate, and optimizer
  criterion = nn.CrossEntropyLoss()
  learning_rate = 0.001
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  trainer=ModelTrainer(model, train_loader, criterion, optimizer, device)

  print('start training')
  # Training loop

  num_epochs = 5
  for epoch in range(num_epochs):
      print(epoch)
      loss = trainer.train()
      # Evaluate the model on the validation set
      validation_loss = trainer.evaluate(val_loader)
      print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss:.4f}, Validation Loss: {validation_loss:.4f}")

  # Evaluation on test set
  test_loss = trainer.evaluate(test_loader)

  return test_loss

# %%
def grid_search(batch_sizes, learning_rates,repeat):
  input_size = 100
  hidden_size = 256
  num_layers = 1
  num_epochs = 10
  results = [[0 for i in range(len(learning_rates))] for j in range((len(batch_sizes)))]

  for i,batch_size in enumerate(batch_sizes):
    for j,learning_rate in enumerate(learning_rates):
      for r in range(repeat):
        results[i][j]+=train_and_test(input_size,hidden_size,num_layers,num_epochs,batch_size,learning_rate)
      results[i][j]/=repeat

  return results

# %%
batch_sizes=[10,100,500]
learning_rates=[0.0001,0.001,0.01]
repeat=2
results = grid_search(batch_sizes,learning_rates,repeat)
print(results)
# Out:
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.8686, Validation Loss: 3.2175
# 1
# Epoch 2/5, Loss: 3.1708, Validation Loss: 3.1643
# 2
# Epoch 3/5, Loss: 3.1407, Validation Loss: 3.1385
# 3
# Epoch 4/5, Loss: 3.0934, Validation Loss: 3.0586
# 4
# Epoch 5/5, Loss: 2.9809, Validation Loss: 2.9213
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.8772, Validation Loss: 3.2170
# 1
# Epoch 2/5, Loss: 3.1682, Validation Loss: 3.1690
# 2
# Epoch 3/5, Loss: 3.1449, Validation Loss: 3.1475
# 3
# Epoch 4/5, Loss: 3.1048, Validation Loss: 3.0800
# 4
# Epoch 5/5, Loss: 3.0006, Validation Loss: 2.9457
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.9313, Validation Loss: 3.2361
# 1
# Epoch 2/5, Loss: 3.1686, Validation Loss: 3.1763
# 2
# Epoch 3/5, Loss: 3.1396, Validation Loss: 3.1486
# 3
# Epoch 4/5, Loss: 3.0990, Validation Loss: 3.0819
# 4
# Epoch 5/5, Loss: 3.0001, Validation Loss: 2.9640
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.8775, Validation Loss: 3.2285
# 1
# Epoch 2/5, Loss: 3.1660, Validation Loss: 3.1743
# 2
# Epoch 3/5, Loss: 3.1480, Validation Loss: 3.1653
# 3
# Epoch 4/5, Loss: 3.1352, Validation Loss: 3.1385
# 4
# Epoch 5/5, Loss: 3.0819, Validation Loss: 3.0418
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.9040, Validation Loss: 3.2378
# 1
# Epoch 2/5, Loss: 3.1687, Validation Loss: 3.1780
# 2
# Epoch 3/5, Loss: 3.1431, Validation Loss: 3.1587
# 3
# Epoch 4/5, Loss: 3.1130, Validation Loss: 3.1131
# 4
# Epoch 5/5, Loss: 3.0165, Validation Loss: 2.9704
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.9425, Validation Loss: 3.2248
# 1
# Epoch 2/5, Loss: 3.1729, Validation Loss: 3.1677
# 2
# Epoch 3/5, Loss: 3.1334, Validation Loss: 3.1237
# 3
# Epoch 4/5, Loss: 3.0603, Validation Loss: 3.0154
# 4
# Epoch 5/5, Loss: 2.9216, Validation Loss: 2.8727
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.9173, Validation Loss: 3.2667
# 1
# Epoch 2/5, Loss: 3.1716, Validation Loss: 3.1866
# 2
# Epoch 3/5, Loss: 3.1417, Validation Loss: 3.1625
# 3
# Epoch 4/5, Loss: 3.0971, Validation Loss: 3.0831
# 4
# Epoch 5/5, Loss: 2.9670, Validation Loss: 2.9025
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.8918, Validation Loss: 3.2170
# 1
# Epoch 2/5, Loss: 3.1670, Validation Loss: 3.1609
# 2
# Epoch 3/5, Loss: 3.1365, Validation Loss: 3.1200
# 3
# Epoch 4/5, Loss: 3.0714, Validation Loss: 3.0201
# 4
# Epoch 5/5, Loss: 2.9469, Validation Loss: 2.8822
# Data Loaded
# start training
# 0
# Epoch 1/5, Loss: 3.8954, Validation Loss: 3.2421
# 1
# Epoch 2/5, Loss: 3.1671, Validation Loss: 3.1817
# 2
# Epoch 3/5, Loss: 3.1448, Validation Loss: 3.1696
# 3
# Epoch 4/5, Loss: 3.1144, Validation Loss: 3.1128
# 4
# Epoch 5/5, Loss: 3.0234, Validation Loss: 2.9910
# [[2.922704517841339, 2.9386830925941467, 2.9042253494262695], [2.903670847415924, 2.8941633105278015, 2.9370177388191223], [3.014752209186554, 2.8801955580711365, 2.925848603248596]]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
plt.imshow(results, interpolation='nearest')
ax.set_yticks(np.arange(len(batch_sizes)), labels=batch_sizes)
ax.set_xticks(np.arange(len(learning_rates)), labels=learning_rates)
plt.xlabel("learning rate")
plt.ylabel("batch size")
for i in range(len(batch_sizes)):
    for j in range(len(learning_rates)):
        text = ax.text(j, i, round(results[i][j],3),ha="center", va="center", color="w")
plt.show()
